# %%
import requests
from bs4 import BeautifulSoup
import smtplib
import time
import pywhatkit
import datetime

rupee = u"\u20B9"
price_formatted = ""
budget = 400

URL = "https://www.amazon.in/Myth-Sisyphus-Vintage-International/dp/0525564454/ref=sr_1_2?crid=2KIPZD79K21RB&keywords=the+myth+of+sisyphus+albert+camus&qid=1667159558&qu=eyJxc2MiOiIxLjY5IiwicXNhIjoiMS4xMiIsInFzcCI6IjAuODEifQ%3D%3D&sprefix=the+myth+of+s%2Caps%2C1413&sr=8-2"

headers = {
    "User=Agent" : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'
}

def checkPrice():
    page = requests.get(URL ,  headers=headers)
 soup = BeautifulSoup(page.content , 'html.parser')

    global title

    title = soup.find(id = "productTitle").get_text()

    global price

    price = soup.find(id = "price").get_text()

    temp = price.replace(rupee , "")

    price_formatted = float(temp)

    if(price_formatted  < budget):
        print(title.strip())
        print(price_formatted)



    if(price_formatted < budget):
        send_email()
        send_whatsapp()
def send_email():
    server = smtplib.SMTP('smtp.gmail.com' , 587)
    server.ehlo()
    server.starttls()
    server.ehlo()

    server.login('pguy46387@gmail.com' , "euqkatedpwrgmbys")

    subject = "Sasta Ho Gya!"
    body = URL

    msg = f"Subject: {subject}\n\n{body}"

    server.sendmail('pguy46387@gmail.com' ,
                   'mrityunjay_ee20b14_61@dtu.ac.in',
                   msg
                   )

    print('HEY EMAIL HAS BEEN SENT!')

    server.quit()

def send_whatsapp():
    now = datetime.datetime.now()
    hour = int(now.strftime("%H"))
    minute = int(now.strftime("%M"))
 # print(hour)
    # print(minute)

    pywhatkit.sendwhatmsg("+919599661020" , title + "\n\n\n"  + URL + "\n\n\n" + "Itne mai mil rahi hai: " + price , hour, minute + 2 ,10 , True ,5)
    pywhatkit.sendwhatmsg()

while (True):
    checkPrice()
    time.sleep(86400)
